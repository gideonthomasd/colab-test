# %% [markdown]
# <a href="https://colab.research.google.com/github/gideonthomasd/colab-test/blob/master/MountainCar001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gym
import gym
import random
env = gym.make("MountainCar-v0")
env.reset()
done = False
while not done:
  action = random.randint(0,2)
  new_state, reward, done, _ = env.step(action)
  print(new_state, done)

env.close()
# Out:
# ...
# [-5.43172960e-01  1.47828813e-04] False
# [-0.54187841  0.00129455] False
# [-0.53944683  0.00243158] False
# [-0.53589643  0.0035504 ] False
# [-0.53125383  0.00464261] False
# [-0.52555381  0.00570001] False
# [-0.52083914  0.00471468] False
# [-0.51514516  0.00569398] False
# [-0.50851457  0.00663058] False
# [-0.50099708  0.00751749] False
# [-0.49464897  0.00634811] False
# [-0.48751771  0.00713126] False
# [-0.47965653  0.00786118] False
# [-0.47312397  0.00653257] False
# [-0.46596852  0.00715545] False
# [-0.46024315  0.00572537] False
# [-0.45399009  0.00625306] False
# [-0.4482553   0.00573478] False
# [-0.4420808   0.00617451] False
# [-0.4355116  0.0065692] False
# [-0.4295954   0.00591621] False
# [-0.42537491  0.00422049] False
# [-0.42188049  0.00349442] False
# [-0.41913716  0.00274332] False
# [-0.41816454  0.00097262] False
# [-0.41896956 -0.00080502] False
# [-0.41954647 -0.00057691] False
# [-0.42089117 -0.00134469] False
# [-0.42399404 -0.00310287] False
# ...

# %% [markdown]
# The imports are fine
